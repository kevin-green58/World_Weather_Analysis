# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_keys

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 51.1,
#   'feels_like': 42.75,
#   'temp_min': 50,
#   'temp_max': 52,
#   'pressure': 1021,
#   'humidity': 53},
#  'visibility': 10000,
#  'wind': {'speed': 9.17, 'deg': 330},
#  'clouds': {'all': 75},
#  'dt': 1603833838,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1603797111,
#   'sunset': 1603835043},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
# Create an empty list to hold the weather data.
weather_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        weather_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | bontang
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | porto walter
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | vinh
# Processing Record 8 of Set 1 | alofi
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | troitsko-pechorsk
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | clarence town
# Processing Record 18 of Set 1 | puerto narino
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | komsomolskiy
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | ironton
# Processing Record 24 of Set 1 | kloulklubed
# Processing Record 25 of Set 1 | pierre
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | kyzyl-suu
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | san jose
# Processing Record 31 of Set 1 | dubrovnik
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | bitam
# Processing Record 34 of Set 1 | ewa beach
# Processing Record 35 of Set 1 | avera
# Processing Record 36 of Set 1 | egvekinot
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | antalaha
# Processing Record 39 of Set 1 | buraydah
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | bykovo
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | touros
# Processing Record 45 of Set 1 | mahajanga
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | olafsvik
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | las cruces
# Processing Record 50 of Set 1 | sao filipe
# Processing Record 1 of Set 2 | huarmey
# Processing Record 2 of Set 2 | bathsheba
# Processing Record 3 of Set 2 | kununurra
# Processing Record 4 of Set 2 | le port
# Processing Record 5 of Set 2 | luderitz
# Processing Record 6 of Set 2 | luanda
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | pevek
# Processing Record 11 of Set 2 | tawzar
# City not found. Skipping...
# Processing Record 12 of Set 2 | general roca
# Processing Record 13 of Set 2 | iqaluit
# Processing Record 14 of Set 2 | kawalu
# Processing Record 15 of Set 2 | the pas
# Processing Record 16 of Set 2 | inverell
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | inverness
# Processing Record 22 of Set 2 | sur
# Processing Record 23 of Set 2 | sergeyevka
# Processing Record 24 of Set 2 | arlit
# Processing Record 25 of Set 2 | ushtobe
# Processing Record 26 of Set 2 | biak
# Processing Record 27 of Set 2 | linqiong
# Processing Record 28 of Set 2 | port macquarie
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | burgeo
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | port blair
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | comodoro rivadavia
# Processing Record 36 of Set 2 | ambilobe
# Processing Record 37 of Set 2 | meulaboh
# Processing Record 38 of Set 2 | lagoa
# Processing Record 39 of Set 2 | chapais
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | forio
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | saint-augustin
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | dwarka
# Processing Record 46 of Set 2 | sao jose da coroa grande
# Processing Record 47 of Set 2 | kokopo
# Processing Record 48 of Set 2 | klaksvik
# Processing Record 49 of Set 2 | la ronge
# Processing Record 50 of Set 2 | mataura
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | ucluelet
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | hermanus
# Processing Record 5 of Set 3 | botwood
# Processing Record 6 of Set 3 | arman
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 10 of Set 3 | kapaa
# Processing Record 11 of Set 3 | ust-tsilma
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | panaba
# Processing Record 14 of Set 3 | nacala
# Processing Record 15 of Set 3 | pinheiro machado
# Processing Record 16 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 17 of Set 3 | khani
# Processing Record 18 of Set 3 | turkistan
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | nouadhibou
# Processing Record 21 of Set 3 | vao
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | sinnamary
# Processing Record 25 of Set 3 | izhma
# Processing Record 26 of Set 3 | abalak
# Processing Record 27 of Set 3 | feira de santana
# Processing Record 28 of Set 3 | sambava
# Processing Record 29 of Set 3 | qaanaaq
# Processing Record 30 of Set 3 | asau
# Processing Record 31 of Set 3 | tigil
# Processing Record 32 of Set 3 | sola
# Processing Record 33 of Set 3 | ola
# Processing Record 34 of Set 3 | waitati
# Processing Record 35 of Set 3 | galesong
# Processing Record 36 of Set 3 | bondoukou
# Processing Record 37 of Set 3 | hofn
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | savino
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | roebourne
# Processing Record 42 of Set 3 | hendijan
# City not found. Skipping...
# Processing Record 43 of Set 3 | loandjili
# Processing Record 44 of Set 3 | bolivar
# Processing Record 45 of Set 3 | codrington
# Processing Record 46 of Set 3 | bajos de haina
# Processing Record 47 of Set 3 | banda aceh
# Processing Record 48 of Set 3 | vila franca do campo
# Processing Record 49 of Set 3 | svetlogorsk
# Processing Record 50 of Set 3 | talakan
# Processing Record 1 of Set 4 | amapa
# Processing Record 2 of Set 4 | san lorenzo de el escorial
# Processing Record 3 of Set 4 | novyy nekouz
# Processing Record 4 of Set 4 | glace bay
# Processing Record 5 of Set 4 | carpinteria
# Processing Record 6 of Set 4 | nyurba
# Processing Record 7 of Set 4 | hobart
# Processing Record 8 of Set 4 | livingston
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | voyvozh
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | juneau
# Processing Record 13 of Set 4 | sernovodsk
# Processing Record 14 of Set 4 | murgab
# Processing Record 15 of Set 4 | oktyabrskoye
# Processing Record 16 of Set 4 | tornio
# Processing Record 17 of Set 4 | naze
# Processing Record 18 of Set 4 | sungaipenuh
# Processing Record 19 of Set 4 | cabo san lucas
# Processing Record 20 of Set 4 | bac lieu
# Processing Record 21 of Set 4 | dauphin
# Processing Record 22 of Set 4 | dingle
# Processing Record 23 of Set 4 | tura
# Processing Record 24 of Set 4 | mont-dore
# Processing Record 25 of Set 4 | bredasdorp
# Processing Record 26 of Set 4 | ndele
# Processing Record 27 of Set 4 | merauke
# Processing Record 28 of Set 4 | port elizabeth
# Processing Record 29 of Set 4 | yongan
# Processing Record 30 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 4 | alice springs
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | kushiro
# Processing Record 35 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 4 | san nicolas
# Processing Record 37 of Set 4 | fare
# Processing Record 38 of Set 4 | gerede
# Processing Record 39 of Set 4 | yiyang
# Processing Record 40 of Set 4 | mount gambier
# Processing Record 41 of Set 4 | honningsvag
# Processing Record 42 of Set 4 | dibulla
# Processing Record 43 of Set 4 | vredendal
# Processing Record 44 of Set 4 | mujiayingzi
# Processing Record 45 of Set 4 | deniliquin
# Processing Record 46 of Set 4 | homer
# Processing Record 47 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 4 | pasni
# Processing Record 49 of Set 4 | mocuba
# Processing Record 50 of Set 4 | suao
# City not found. Skipping...
# Processing Record 1 of Set 5 | buchanan
# Processing Record 2 of Set 5 | atikokan
# Processing Record 3 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | saskylakh
# Processing Record 7 of Set 5 | ilulissat
# Processing Record 8 of Set 5 | tual
# Processing Record 9 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 5 | port alfred
# Processing Record 11 of Set 5 | ostrovnoy
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | noshiro
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | khatanga
# Processing Record 16 of Set 5 | gamba
# Processing Record 17 of Set 5 | selma
# Processing Record 18 of Set 5 | tezu
# Processing Record 19 of Set 5 | constitucion
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | asha
# Processing Record 22 of Set 5 | santiago del estero
# Processing Record 23 of Set 5 | lata
# Processing Record 24 of Set 5 | westport
# Processing Record 25 of Set 5 | taunggyi
# Processing Record 26 of Set 5 | imbituba
# Processing Record 27 of Set 5 | esil
# Processing Record 28 of Set 5 | tasiilaq
# Processing Record 29 of Set 5 | port augusta
# Processing Record 30 of Set 5 | taltal
# Processing Record 31 of Set 5 | kavieng
# Processing Record 32 of Set 5 | yomou
# Processing Record 33 of Set 5 | ugoofaaru
# Processing Record 34 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 5 | woudenberg
# Processing Record 36 of Set 5 | bethel
# Processing Record 37 of Set 5 | hilo
# Processing Record 38 of Set 5 | rio de janeiro
# Processing Record 39 of Set 5 | muros
# Processing Record 40 of Set 5 | cidreira
# Processing Record 41 of Set 5 | saltpond
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | arawa
# Processing Record 44 of Set 5 | inhambane
# Processing Record 45 of Set 5 | tazovskiy
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | makubetsu
# Processing Record 48 of Set 5 | puri
# Processing Record 49 of Set 5 | cherepovets
# Processing Record 50 of Set 5 | newport
# Processing Record 1 of Set 6 | claremorris
# Processing Record 2 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 3 of Set 6 | souillac
# Processing Record 4 of Set 6 | llangefni
# Processing Record 5 of Set 6 | tautira
# Processing Record 6 of Set 6 | cienfuegos
# Processing Record 7 of Set 6 | avarua
# Processing Record 8 of Set 6 | rio gallegos
# Processing Record 9 of Set 6 | saint-francois
# Processing Record 10 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 6 | bambanglipuro
# Processing Record 12 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 6 | ballina
# Processing Record 14 of Set 6 | enugu
# Processing Record 15 of Set 6 | burnie
# Processing Record 16 of Set 6 | seoul
# Processing Record 17 of Set 6 | asfi
# Processing Record 18 of Set 6 | tessalit
# Processing Record 19 of Set 6 | vaitape
# Processing Record 20 of Set 6 | cascais
# Processing Record 21 of Set 6 | saqqez
# Processing Record 22 of Set 6 | sarahan
# Processing Record 23 of Set 6 | roald
# Processing Record 24 of Set 6 | pietarsaari
# Processing Record 25 of Set 6 | zabid
# Processing Record 26 of Set 6 | manta
# Processing Record 27 of Set 6 | cayenne
# Processing Record 28 of Set 6 | jinxiang
# Processing Record 29 of Set 6 | gazanjyk
# Processing Record 30 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | natalio
# Processing Record 33 of Set 6 | masterton
# Processing Record 34 of Set 6 | mikhaylov
# Processing Record 35 of Set 6 | san rafael
# Processing Record 36 of Set 6 | yerbogachen
# Processing Record 37 of Set 6 | severnyy
# Processing Record 38 of Set 6 | aktau
# Processing Record 39 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 40 of Set 6 | key west
# Processing Record 41 of Set 6 | sitka
# Processing Record 42 of Set 6 | general delgado
# Processing Record 43 of Set 6 | keuruu
# Processing Record 44 of Set 6 | yerofey pavlovich
# Processing Record 45 of Set 6 | dordrecht
# Processing Record 46 of Set 6 | ylojarvi
# Processing Record 47 of Set 6 | adrar
# Processing Record 48 of Set 6 | chhatarpur
# Processing Record 49 of Set 6 | terra santa
# Processing Record 50 of Set 6 | aras
# Processing Record 1 of Set 7 | berlevag
# Processing Record 2 of Set 7 | bonthe
# Processing Record 3 of Set 7 | puerto escondido
# Processing Record 4 of Set 7 | sibut
# Processing Record 5 of Set 7 | juazeiro
# Processing Record 6 of Set 7 | lorengau
# Processing Record 7 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 7 | surt
# Processing Record 9 of Set 7 | hohhot
# Processing Record 10 of Set 7 | port hardy
# Processing Record 11 of Set 7 | arbazh
# Processing Record 12 of Set 7 | poum
# Processing Record 13 of Set 7 | la rochelle
# Processing Record 14 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 7 | bandar maharani
# City not found. Skipping...
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | trofors
# Processing Record 18 of Set 7 | samarai
# Processing Record 19 of Set 7 | narsaq
# Processing Record 20 of Set 7 | mandali
# Processing Record 21 of Set 7 | dongsheng
# Processing Record 22 of Set 7 | torbay
# Processing Record 23 of Set 7 | hasaki
# Processing Record 24 of Set 7 | kirkwall
# Processing Record 25 of Set 7 | qasigiannguit
# Processing Record 26 of Set 7 | uttiramerur
# Processing Record 27 of Set 7 | mitzic
# Processing Record 28 of Set 7 | aksu
# Processing Record 29 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 7 | upernavik
# Processing Record 31 of Set 7 | prince rupert
# Processing Record 32 of Set 7 | moose factory
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | wenling
# Processing Record 35 of Set 7 | pangody
# Processing Record 36 of Set 7 | wanaka
# Processing Record 37 of Set 7 | goderich
# Processing Record 38 of Set 7 | vangaindrano
# Processing Record 39 of Set 7 | khartoum
# Processing Record 40 of Set 7 | mandalgovi
# Processing Record 41 of Set 7 | show low
# Processing Record 42 of Set 7 | kenai
# Processing Record 43 of Set 7 | hinton
# Processing Record 44 of Set 7 | dunedin
# Processing Record 45 of Set 7 | oriximina
# Processing Record 46 of Set 7 | zeya
# Processing Record 47 of Set 7 | bairiki
# Processing Record 48 of Set 7 | acapulco
# Processing Record 49 of Set 7 | bengkulu
# Processing Record 50 of Set 7 | esperance
# Processing Record 1 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 8 | dikson
# Processing Record 3 of Set 8 | parabel
# Processing Record 4 of Set 8 | matane
# Processing Record 5 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 8 | warwick
# Processing Record 7 of Set 8 | itaituba
# Processing Record 8 of Set 8 | iranshahr
# Processing Record 9 of Set 8 | airai
# Processing Record 10 of Set 8 | jian
# Processing Record 11 of Set 8 | clyde river
# Processing Record 12 of Set 8 | bardiyah
# Processing Record 13 of Set 8 | bilma
# Processing Record 14 of Set 8 | tambovka
# Processing Record 15 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 8 | blagoyevo
# Processing Record 17 of Set 8 | kongolo
# Processing Record 18 of Set 8 | mimongo
# Processing Record 19 of Set 8 | fort myers beach
# Processing Record 20 of Set 8 | chuy
# Processing Record 21 of Set 8 | peravurani
# Processing Record 22 of Set 8 | nome
# Processing Record 23 of Set 8 | sorong
# Processing Record 24 of Set 8 | chato
# Processing Record 25 of Set 8 | mareeba
# Processing Record 26 of Set 8 | alta floresta
# Processing Record 27 of Set 8 | pendleton
# Processing Record 28 of Set 8 | pafos
# Processing Record 29 of Set 8 | kalmanka
# Processing Record 30 of Set 8 | vila velha
# Processing Record 31 of Set 8 | yatou
# Processing Record 32 of Set 8 | shinshiro
# Processing Record 33 of Set 8 | genhe
# Processing Record 34 of Set 8 | pangnirtung
# Processing Record 35 of Set 8 | geraldton
# Processing Record 36 of Set 8 | yulara
# Processing Record 37 of Set 8 | kargasok
# Processing Record 38 of Set 8 | mana
# Processing Record 39 of Set 8 | kashi
# Processing Record 40 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 8 | san quintin
# Processing Record 42 of Set 8 | shentala
# Processing Record 43 of Set 8 | taoudenni
# Processing Record 44 of Set 8 | monatele
# City not found. Skipping...
# Processing Record 45 of Set 8 | gao
# Processing Record 46 of Set 8 | vestmannaeyjar
# Processing Record 47 of Set 8 | jiangyou
# Processing Record 48 of Set 8 | baykit
# Processing Record 49 of Set 8 | quatre cocos
# Processing Record 50 of Set 8 | lavrentiya
# Processing Record 1 of Set 9 | dobrun
# Processing Record 2 of Set 9 | talaya
# Processing Record 3 of Set 9 | tema
# Processing Record 4 of Set 9 | bolpur
# Processing Record 5 of Set 9 | atbasar
# Processing Record 6 of Set 9 | cabra
# Processing Record 7 of Set 9 | kedougou
# Processing Record 8 of Set 9 | buala
# Processing Record 9 of Set 9 | paamiut
# Processing Record 10 of Set 9 | anloga
# Processing Record 11 of Set 9 | millerovo
# Processing Record 12 of Set 9 | okhotsk
# Processing Record 13 of Set 9 | ponta delgada
# Processing Record 14 of Set 9 | husavik
# Processing Record 15 of Set 9 | presidente dutra
# Processing Record 16 of Set 9 | kondrovo
# Processing Record 17 of Set 9 | uttarkashi
# Processing Record 18 of Set 9 | kuytun
# Processing Record 19 of Set 9 | ziyang
# Processing Record 20 of Set 9 | henties bay
# Processing Record 21 of Set 9 | la asuncion
# Processing Record 22 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 23 of Set 9 | flagstaff
# Processing Record 24 of Set 9 | changli
# Processing Record 25 of Set 9 | khandyga
# Processing Record 26 of Set 9 | tecoanapa
# Processing Record 27 of Set 9 | kuragino
# Processing Record 28 of Set 9 | altamira
# Processing Record 29 of Set 9 | ayagoz
# Processing Record 30 of Set 9 | hay river
# Processing Record 31 of Set 9 | grand gaube
# Processing Record 32 of Set 9 | trincomalee
# Processing Record 33 of Set 9 | havoysund
# Processing Record 34 of Set 9 | pandharpur
# Processing Record 35 of Set 9 | san
# Processing Record 36 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 9 | posse
# Processing Record 38 of Set 9 | pecos
# Processing Record 39 of Set 9 | kavaratti
# Processing Record 40 of Set 9 | sungairaya
# Processing Record 41 of Set 9 | northam
# Processing Record 42 of Set 9 | sandnessjoen
# Processing Record 43 of Set 9 | usinsk
# Processing Record 44 of Set 9 | bagaces
# Processing Record 45 of Set 9 | jumla
# Processing Record 46 of Set 9 | east london
# Processing Record 47 of Set 9 | gweta
# Processing Record 48 of Set 9 | juybar
# Processing Record 49 of Set 9 | nesbyen
# Processing Record 50 of Set 9 | kamenka
# Processing Record 1 of Set 10 | norsup
# Processing Record 2 of Set 10 | praia da vitoria
# Processing Record 3 of Set 10 | alice
# Processing Record 4 of Set 10 | doume
# Processing Record 5 of Set 10 | maryborough
# Processing Record 6 of Set 10 | zhuhai
# Processing Record 7 of Set 10 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | kruisfontein
# Processing Record 10 of Set 10 | mersing
# Processing Record 11 of Set 10 | nioki
# Processing Record 12 of Set 10 | powell river
# Processing Record 13 of Set 10 | san patricio
# Processing Record 14 of Set 10 | shimanovsk
# Processing Record 15 of Set 10 | buin
# Processing Record 16 of Set 10 | spring valley
# Processing Record 17 of Set 10 | nelson bay
# Processing Record 18 of Set 10 | caramay
# Processing Record 19 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 10 | gat
# Processing Record 21 of Set 10 | ishimbay
# Processing Record 22 of Set 10 | yueyang
# Processing Record 23 of Set 10 | gambela
# Processing Record 24 of Set 10 | jiuquan
# Processing Record 25 of Set 10 | mackay
# Processing Record 26 of Set 10 | grand island
# Processing Record 27 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 10 | guzelyurt
# Processing Record 29 of Set 10 | longyearbyen
# Processing Record 30 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 10 | bahia blanca
# Processing Record 32 of Set 10 | atambua
# Processing Record 33 of Set 10 | xiongshi
# City not found. Skipping...
# Processing Record 34 of Set 10 | griffith
# Processing Record 35 of Set 10 | aykhal
# Processing Record 36 of Set 10 | baoqing
# Processing Record 37 of Set 10 | nanakuli
# Processing Record 38 of Set 10 | garowe
# Processing Record 39 of Set 10 | santa lucia
# Processing Record 40 of Set 10 | luangwa
# Processing Record 41 of Set 10 | edd
# Processing Record 42 of Set 10 | zonguldak
# Processing Record 43 of Set 10 | faanui
# Processing Record 44 of Set 10 | sao paulo de olivenca
# Processing Record 45 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 10 | siderno
# Processing Record 47 of Set 10 | humberto de campos
# Processing Record 48 of Set 10 | veraval
# Processing Record 49 of Set 10 | at-bashi
# Processing Record 50 of Set 10 | zunyi
# Processing Record 1 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 11 | padang
# Processing Record 3 of Set 11 | kihei
# Processing Record 4 of Set 11 | sadiqabad
# Processing Record 5 of Set 11 | aklavik
# Processing Record 6 of Set 11 | oranjemund
# Processing Record 7 of Set 11 | boa vista
# Processing Record 8 of Set 11 | maracaju
# Processing Record 9 of Set 11 | dalbandin
# Processing Record 10 of Set 11 | nylstroom
# City not found. Skipping...
# Processing Record 11 of Set 11 | rosario oeste
# Processing Record 12 of Set 11 | nhulunbuy
# Processing Record 13 of Set 11 | ossora
# Processing Record 14 of Set 11 | assiniboia
# Processing Record 15 of Set 11 | natitingou
# Processing Record 16 of Set 11 | lompoc
# Processing Record 17 of Set 11 | morondava
# Processing Record 18 of Set 11 | namibe
# Processing Record 19 of Set 11 | yarmouth
# Processing Record 20 of Set 11 | dubbo
# Processing Record 21 of Set 11 | bourail
# Processing Record 22 of Set 11 | karlstad
# Processing Record 23 of Set 11 | salinopolis
# Processing Record 24 of Set 11 | port lincoln
# Processing Record 25 of Set 11 | saint-georges
# Processing Record 26 of Set 11 | trat
# Processing Record 27 of Set 11 | zhezkazgan
# Processing Record 28 of Set 11 | musoma
# Processing Record 29 of Set 11 | kommunar
# Processing Record 30 of Set 11 | fort nelson
# Processing Record 31 of Set 11 | ancud
# Processing Record 32 of Set 11 | chernyshevskiy
# Processing Record 33 of Set 11 | portland
# Processing Record 34 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 11 | ketchikan
# Processing Record 36 of Set 11 | atar
# Processing Record 37 of Set 11 | punta alta
# Processing Record 38 of Set 11 | salalah
# Processing Record 39 of Set 11 | antofagasta
# Processing Record 40 of Set 11 | maldonado
# Processing Record 41 of Set 11 | jalu
# Processing Record 42 of Set 11 | esmeraldas
# Processing Record 43 of Set 11 | fairbanks
# Processing Record 44 of Set 11 | harlingen
# Processing Record 45 of Set 11 | bacolod
# Processing Record 46 of Set 11 | sinjar
# Processing Record 47 of Set 11 | hambantota
# Processing Record 48 of Set 11 | borogontsy
# Processing Record 49 of Set 11 | lagunas
# Processing Record 50 of Set 11 | grindavik
# Processing Record 1 of Set 12 | tuensang
# Processing Record 2 of Set 12 | netarhat
# Processing Record 3 of Set 12 | coahuayana
# Processing Record 4 of Set 12 | moba
# Processing Record 5 of Set 12 | north augusta
# Processing Record 6 of Set 12 | tatvan
# Processing Record 7 of Set 12 | san lorenzo
# Processing Record 8 of Set 12 | vardo
# Processing Record 9 of Set 12 | umm lajj
# Processing Record 10 of Set 12 | cap malheureux
# Processing Record 11 of Set 12 | leningradskiy
# Processing Record 12 of Set 12 | puerto madero
# Processing Record 13 of Set 12 | lerum
# Processing Record 14 of Set 12 | talnakh
# Processing Record 15 of Set 12 | malakal
# Processing Record 16 of Set 12 | manadhoo
# Processing Record 17 of Set 12 | kochinda
# Processing Record 18 of Set 12 | road town
# Processing Record 19 of Set 12 | kokkola
# Processing Record 20 of Set 12 | the valley
# Processing Record 21 of Set 12 | mesto albrechtice
# Processing Record 22 of Set 12 | dakar
# Processing Record 23 of Set 12 | beloha
# Processing Record 24 of Set 12 | red bank
# Processing Record 25 of Set 12 | beringovskiy
# Processing Record 26 of Set 12 | hobyo
# Processing Record 27 of Set 12 | tigzirt
# Processing Record 28 of Set 12 | margate
# Processing Record 29 of Set 12 | rincon
# Processing Record 30 of Set 12 | mucurapo
# Processing Record 31 of Set 12 | marawi
# Processing Record 32 of Set 12 | chulman
# Processing Record 33 of Set 12 | shima
# Processing Record 34 of Set 12 | porto novo
# Processing Record 35 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 12 | sri aman
# Processing Record 37 of Set 12 | pallasovka
# Processing Record 38 of Set 12 | mabaruma
# Processing Record 39 of Set 12 | skibbereen
# Processing Record 40 of Set 12 | goshogawara
# Processing Record 41 of Set 12 | college
# Processing Record 42 of Set 12 | hawalli
# Processing Record 43 of Set 12 | marsh harbour
# Processing Record 44 of Set 12 | tatawin
# Processing Record 45 of Set 12 | revda
# Processing Record 46 of Set 12 | minbu
# Processing Record 47 of Set 12 | gerash
# Processing Record 48 of Set 12 | tirumullaivasal
# Processing Record 49 of Set 12 | maxixe
# Processing Record 50 of Set 12 | kadoma
# Processing Record 1 of Set 13 | kaeo
# Processing Record 2 of Set 13 | kandiari
# Processing Record 3 of Set 13 | tuatapere
# Processing Record 4 of Set 13 | pali
# Processing Record 5 of Set 13 | mundo nuevo
# Processing Record 6 of Set 13 | anahuac
# Processing Record 7 of Set 13 | namatanai
# Processing Record 8 of Set 13 | port hueneme
# Processing Record 9 of Set 13 | ginda
# Processing Record 10 of Set 13 | karratha
# Processing Record 11 of Set 13 | labuhan
# Processing Record 12 of Set 13 | kutum
# Processing Record 13 of Set 13 | batagay-alyta
# Processing Record 14 of Set 13 | labuan
# Processing Record 15 of Set 13 | santa ines
# Processing Record 16 of Set 13 | balkhash
# Processing Record 17 of Set 13 | cuamba
# Processing Record 18 of Set 13 | faya
# Processing Record 19 of Set 13 | manavalakurichi
# Processing Record 20 of Set 13 | coquimbo
# Processing Record 21 of Set 13 | lodja
# Processing Record 22 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 13 | kudahuvadhoo
# Processing Record 24 of Set 13 | menongue
# Processing Record 25 of Set 13 | bichena
# Processing Record 26 of Set 13 | marevo
# Processing Record 27 of Set 13 | kamina
# Processing Record 28 of Set 13 | vung tau
# Processing Record 29 of Set 13 | tiznit
# Processing Record 30 of Set 13 | bhuj
# Processing Record 31 of Set 13 | harper
# Processing Record 32 of Set 13 | san ignacio
# Processing Record 33 of Set 13 | novyy buyan
# Processing Record 34 of Set 13 | misratah
# Processing Record 35 of Set 13 | urdoma
# Processing Record 36 of Set 13 | san jeronimo
# Processing Record 37 of Set 13 | gilgit
# Processing Record 38 of Set 13 | hovd
# Processing Record 39 of Set 13 | iralaya
# Processing Record 40 of Set 13 | eureka
# Processing Record 41 of Set 13 | korla
# Processing Record 42 of Set 13 | oranjestad
# Processing Record 43 of Set 13 | flin flon
# Processing Record 44 of Set 13 | silver city
# Processing Record 45 of Set 13 | keti bandar
# Processing Record 46 of Set 13 | barra dos coqueiros
# Processing Record 47 of Set 13 | caranavi
# Processing Record 48 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 49 of Set 13 | bikin
# Processing Record 50 of Set 13 | morro bay
# Processing Record 1 of Set 14 | agadir
# Processing Record 2 of Set 14 | xining
# Processing Record 3 of Set 14 | camocim
# Processing Record 4 of Set 14 | bereda
# Processing Record 5 of Set 14 | neftcala
# Processing Record 6 of Set 14 | grajau
# Processing Record 7 of Set 14 | haines junction
# Processing Record 8 of Set 14 | burica
# City not found. Skipping...
# Processing Record 9 of Set 14 | havre-saint-pierre
# Processing Record 10 of Set 14 | wala
# Processing Record 11 of Set 14 | kieta
# Processing Record 12 of Set 14 | severo-yeniseyskiy
# Processing Record 13 of Set 14 | marienburg
# Processing Record 14 of Set 14 | quchan
# Processing Record 15 of Set 14 | gotsu
# Processing Record 16 of Set 14 | kaura namoda
# Processing Record 17 of Set 14 | lake charles
# Processing Record 18 of Set 14 | mayo
# Processing Record 19 of Set 14 | plettenberg bay
# Processing Record 20 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 14 | barkly west
# Processing Record 22 of Set 14 | englehart
# Processing Record 23 of Set 14 | kalakamati
# Processing Record 24 of Set 14 | kurilsk
# Processing Record 25 of Set 14 | vokhma
# Processing Record 26 of Set 14 | koshurnikovo
# Processing Record 27 of Set 14 | mafinga
# Processing Record 28 of Set 14 | yangambi
# Processing Record 29 of Set 14 | oloron-sainte-marie
# Processing Record 30 of Set 14 | uyuni
# Processing Record 31 of Set 14 | staryy nadym
# Processing Record 32 of Set 14 | kenora
# Processing Record 33 of Set 14 | agua dulce
# Processing Record 34 of Set 14 | beira
# Processing Record 35 of Set 14 | paramonga
# Processing Record 36 of Set 14 | kantabanji
# Processing Record 37 of Set 14 | mangalam
# Processing Record 38 of Set 14 | bandar-e lengeh
# Processing Record 39 of Set 14 | dhidhdhoo
# Processing Record 40 of Set 14 | krasnoselkup
# Processing Record 41 of Set 14 | georgiyevskoye
# Processing Record 42 of Set 14 | olga
# Processing Record 43 of Set 14 | sodertalje
# City not found. Skipping...
# Processing Record 44 of Set 14 | turinsk
# Processing Record 45 of Set 14 | qui nhon
# Processing Record 46 of Set 14 | pangai
# Processing Record 47 of Set 14 | novobelokatay
# Processing Record 48 of Set 14 | del rio
# Processing Record 49 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 50 of Set 14 | gualaquiza
# Processing Record 1 of Set 15 | davila
# Processing Record 2 of Set 15 | udachnyy
# Processing Record 3 of Set 15 | manakara
# Processing Record 4 of Set 15 | natal
# Processing Record 5 of Set 15 | sorsk
# Processing Record 6 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 15 | cabedelo
# Processing Record 8 of Set 15 | barranca de upia
# Processing Record 9 of Set 15 | micheweni
# Processing Record 10 of Set 15 | san pedro
# Processing Record 11 of Set 15 | hervey bay
# Processing Record 12 of Set 15 | uinskoye
# Processing Record 13 of Set 15 | olinda
# Processing Record 14 of Set 15 | valparaiso
# Processing Record 15 of Set 15 | muroto
# Processing Record 16 of Set 15 | mathbaria
# Processing Record 17 of Set 15 | bougouni
# Processing Record 18 of Set 15 | brunico
# Processing Record 19 of Set 15 | ereymentau
# Processing Record 20 of Set 15 | pacifica
# Processing Record 21 of Set 15 | jutai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Busselton -33.65  115.33     54.00        96          22        7.92
# 1         Vaini -21.20 -175.20     75.20        78          40       12.75
# 2       Bontang   0.13  117.50     76.84        86          96        6.71
# 3      Thompson  55.74  -97.86     26.60        63          75        9.17
# 4  Porto Walter  -8.27  -72.74     92.80        47          97        2.33
# 5          Lebu -37.62  -73.65     53.44        66          97       13.44
# 6          Vinh  18.67  105.67     72.99        87          99        8.39
# 7         Alofi -19.06 -169.92     69.80        94          90       14.99
# 8  Punta Arenas -53.15  -70.92     46.40        55           0       21.92
# 9        Albany  42.60  -73.97     50.00        61         100        3.29
#
#   Country       Description
# 0      AU        few clouds
# 1      TO  scattered clouds
# 2      ID   overcast clouds
# 3      CA     broken clouds
# 4      BR   overcast clouds
# 5      CL   overcast clouds
# 6      VN   overcast clouds
# 7      NU       shower rain
# 8      CL         clear sky
# 9      US   overcast clouds

# %%
#Reorder Columns 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
weather_data_df=weather_data_df[new_column_order]
weather_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.65  115.33     54.00        96          22
# 1           Vaini      TO -21.20 -175.20     75.20        78          40
# 2         Bontang      ID   0.13  117.50     76.84        86          96
# 3        Thompson      CA  55.74  -97.86     26.60        63          75
# 4    Porto Walter      BR  -8.27  -72.74     92.80        47          97
# ..            ...     ...    ...     ...       ...       ...         ...
# 662      Bougouni      ML  11.42   -7.48     76.64        33          90
# 663       Brunico      IT  46.80   11.94     32.00        92           0
# 664    Ereymentau      KZ  51.62   73.10     27.55        96           9
# 665      Pacifica      US  37.61 -122.49     75.20        16          20
# 666         Jutai      BR  -5.18  -68.90     91.38        52          62
#
#      Wind Speed       Description
# 0          7.92        few clouds
# 1         12.75  scattered clouds
# 2          6.71   overcast clouds
# 3          9.17     broken clouds
# 4          2.33   overcast clouds
# ..          ...               ...
# 662        1.36   overcast clouds
# 663        5.82         clear sky
# 664       14.14         clear sky
# 665        8.32        few clouds
# 666        1.03     broken clouds
#
# [667 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
